# %%
import requests
import pandas as pd

# Intentamos capturar datos reales de la API de intercambio de monedas
try:
    url = "https://api.exchangerate-api.com/v4/latest/USD"
    respuesta = requests.get(url)
    
    # Verificamos que la petición fue exitosa (código 200)
    respuesta.raise_for_status()
    
    datos = respuesta.json()

    # Creamos un pequeño resumen de los tipos de cambio
    df = pd.DataFrame(datos['rates'].items(), columns=['Moneda', 'Valor'])
    
    print("¡Conexión exitosa! Aquí los primeros datos capturados:")
    print(df.head())

except Exception as e:
    print(f"Error en la conexión: {e}")
# Out:
# ¡Conexión exitosa! Aquí los primeros datos capturados:
#   Moneda   Valor
# 0    USD    1.00
# 1    AED    3.67
# 2    AFN   64.35
# 3    ALL   81.41
# 4    AMD  374.98
