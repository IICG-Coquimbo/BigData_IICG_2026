# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://www.jumbo.cl/frutas-y-verduras"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('div', class_='flex flex-col')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: $2.090$2.090 x kg
# Encontrado: $3.245$6.490 x kg
# Encontrado: $995$1.990 x kg
# Encontrado: $2.490$1.245 x kg
# Encontrado: $6.293$8.990$8.990 x kg
# Encontrado: $1.690$8.450 x kg
# Encontrado: $790$790 x un
# Encontrado: $790$790 x un
# Encontrado: $2.590$8.633 x kg
# Encontrado: $1.445$2.890 x kg
# Encontrado: $3.990$3.990 x kg
# Encontrado: $1.790$597 x un
# Encontrado: $1.390$1.390 x un
# Encontrado: $990$8.250 x kg
# Encontrado: $1.890$1.890 x kg
# Encontrado: $1.650$1.650 x un
# Encontrado: $1.990$1.990 x kg
# Encontrado: $2.690$21.520 x kg
# Encontrado: $990$990 x un
# Encontrado: $1.390$1.390 x un
# Encontrado: $745$1.490 x kg
# Encontrado: $1.295$2.590 x kg
# Encontrado: $1.095$2.190 x kg
# Encontrado: $1.690$3.380 x kg
# Encontrado: $1.490$1.490 x un
# Encontrado: $1.495$2.990 x kg
# Encontrado: $1.300$6.500 x kg
# Encontrado: $2.590$1.295 x un
# Encontrado: $1.290$1.290 x un
# Encontrado: $1.250$1.250 x un
# Encontrado: $1.790$1.790 x kg
# Encontrado: $2.590$1.295 x un
# Encontrado: $1.190$397 x un
# Encontrado: $3.590$1.795 x un
# Encontrado: $2.490$4.980 x kg
