# %%
import requests
from bs4 import BeautifulSoup

# Configuración de entrada
url = "https://finance.yahoo.com/quote/GC=F" # URL Yahoo Finance
headers = {"User-Agent": "Mozilla/5.0"} 

# 1. Petición al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Buscamos la etiqueta y clase que anotamos)
resultados = sopa.find_all('fin-streamer', class_='last-price')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Precio Encontrado: {dato.text.strip()}")
# Out:
# Precio Encontrado: 6,663.50
# Precio Encontrado: 46,847.00
# Precio Encontrado: 24,458.50
# Precio Encontrado: 2,560.40
# Precio Encontrado: 26.95
# Precio Encontrado: 4,576.50
# Precio Encontrado: 70,734.92
# Precio Encontrado: 4.3920
# Precio Encontrado: 161.34
# Precio Encontrado: 101.17
# Precio Encontrado: 134.96
# Precio Encontrado: 183.02
# Precio Encontrado: 372.74
# Precio Encontrado: 52.50
# Precio Encontrado: 113.90
# Precio Encontrado: 95.58
# Precio Encontrado: 20.37
# Precio Encontrado: 94.39
# Precio Encontrado: 7.42
# Precio Encontrado: 101.17
# Precio Encontrado: 11.33
# Precio Encontrado: 20.24
# Precio Encontrado: 14.73
# Precio Encontrado: 175.20
# Precio Encontrado: 10.68
# Precio Encontrado: 7.42
# Precio Encontrado: 44.06
# Precio Encontrado: 3.7900
