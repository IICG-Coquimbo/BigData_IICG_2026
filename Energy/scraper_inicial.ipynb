# %%
import requests
from bs4 import BeautifulSoup

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

todos_los_datos = []

for dato in resultados:
    titulo = dato.find('a')['title']
    
    info = {
        "titulo": titulo,
        "grupo": "Books"
    }
    
    todos_los_datos.append(info)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])
# Out:
# Cantidad de datos: 20
# [{'titulo': 'A Light in the Attic', 'grupo': 'Books'}, {'titulo': 'Tipping the Velvet', 'grupo': 'Books'}, {'titulo': 'Soumission', 'grupo': 'Books'}]

# %%
import requests
from bs4 import BeautifulSoup

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)

sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

for dato in resultados:
    titulo = dato.find('a')['title']
    print("Libro:", titulo)
# Out:
# Libro: A Light in the Attic
# Libro: Tipping the Velvet
# Libro: Soumission
# Libro: Sharp Objects
# Libro: Sapiens: A Brief History of Humankind
# Libro: The Requiem Red
# Libro: The Dirty Little Secrets of Getting Your Dream Job
# Libro: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# Libro: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# Libro: The Black Maria
# Libro: Starving Hearts (Triangular Trade Trilogy, #1)
# Libro: Shakespeare's Sonnets
# Libro: Set Me Free
# Libro: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Libro: Rip it Up and Start Again
# Libro: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Libro: Olio
# Libro: Mesaerion: The Best Science Fiction Stories 1800-1849
# Libro: Libertarianism for Beginners
# Libro: It's Only the Himalayas

# %%
precios = sopa.find_all('p', class_='price_color')

for i in range(len(resultados)):
    titulo = resultados[i].find('a')['title']
    precio = precios[i].text
    
    info = {
        "titulo": titulo,
        "precio": precio
    }
    
    print(info)
# Out:
# {'titulo': 'A Light in the Attic', 'precio': 'Â£51.77'}
# {'titulo': 'Tipping the Velvet', 'precio': 'Â£53.74'}
# {'titulo': 'Soumission', 'precio': 'Â£50.10'}
# {'titulo': 'Sharp Objects', 'precio': 'Â£47.82'}
# {'titulo': 'Sapiens: A Brief History of Humankind', 'precio': 'Â£54.23'}
# {'titulo': 'The Requiem Red', 'precio': 'Â£22.65'}
# {'titulo': 'The Dirty Little Secrets of Getting Your Dream Job', 'precio': 'Â£33.34'}
# {'titulo': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'precio': 'Â£17.93'}
# {'titulo': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'precio': 'Â£22.60'}
# {'titulo': 'The Black Maria', 'precio': 'Â£52.15'}
# {'titulo': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'precio': 'Â£13.99'}
# {'titulo': "Shakespeare's Sonnets", 'precio': 'Â£20.66'}
# {'titulo': 'Set Me Free', 'precio': 'Â£17.46'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(todos_los_datos)
df.to_csv("dataset.csv", index=False)

print("Archivo dataset.csv guardado")
# Out:
# Archivo dataset.csv guardado

# %%
from pymongo import MongoClient

# conexión al contenedor
client = MongoClient('mongodb://mongodb:27017/')

# base de datos
db = client['proyecto_bigdata']

# colección (como tabla)
coleccion = db['datos_scraping']

print("Conexión exitosa a MongoDB")
# Out:
# Conexión exitosa a MongoDB

# %%
todos_los_datos.append(info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 todos_los_datos.append(info)
#
# NameError: name 'todos_los_datos' is not defined

# %%
todos_los_datos = []  # 👈 ESTO ES CLAVE

for dato in resultados:
    titulo = dato.find('a')['title']
    
    documento = {
        "titulo": titulo,
        "grupo": "Energy",
        "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
    }
    
    todos_los_datos.append(documento)
    coleccion.insert_one(documento)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 todos_los_datos = []  # 👈 ESTO ES CLAVE
# ----> 3 for dato in resultados:
#       4     titulo = dato.find('a')['title']
#       6     documento = {
#       7         "titulo": titulo,
#       8         "grupo": "Energy",
#       9         "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
#      10     }
#
# NameError: name 'resultados' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from pymongo import MongoClient

# 1. Conexión MongoDB
client = MongoClient('mongodb://mongodb:27017/')
db = client['proyecto_bigdata']
coleccion = db['datos_scraping']

print("Conexión exitosa a MongoDB")

# 2. Scraping
url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

# 3. Lista
todos_los_datos = []

# 4. Bucle
for dato in resultados:
    titulo = dato.find('a')['title']
    
    documento = {
        "titulo": titulo,
        "grupo": "Energy",
        "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
    }
    
    # Guardar en lista
    todos_los_datos.append(documento)
    
    # Guardar en MongoDB 🔥
    coleccion.insert_one(documento)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])
print("Datos guardados en MongoDB")
# Out:
# Conexión exitosa a MongoDB
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[5], line 40
#      37     todos_los_datos.append(documento)
#      39     # Guardar en MongoDB 🔥
# ---> 40     coleccion.insert_one(documento)
#      42 print("Cantidad de datos:", len(todos_los_datos))
#      43 print(todos_los_datos[:3])
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
# ...

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://bigdata_mongodb:27017/')
db = client['proyecto_bigdata']
coleccion = db['datos_scraping']

print("Conexión exitosa a MongoDB")
# Out:
# Conexión exitosa a MongoDB
