# %%
import requests
from bs4 import BeautifulSoup

# Configuracion de entrada
url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Peticion al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('article', class_='product_pod')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")

#Mostrarlo ordenado (titulo, valor, equipo)
todos_los_datos = [] # Lista vacia para guardar todo

for item in resultados:
 # Creamos el diccionario para ESTE producto
 datos_item = {
     "titulo": item.find('h3').find('a')['title'],
     "valor": item.find('p', class_='price_color').text.strip(),
     "equipo": "E-commerce" # Etiqueta de tu caso de estudio
 }

 # Lo agregamos a nuestra lista general
 todos_los_datos.append(datos_item)

 # Ahora tenemos una "colecci n" lista para MongoDB
print(f"He guardado {len(todos_los_datos)} diccionarios.")

for libros in todos_los_datos:
    print(libros)
# Out:
# Encontrado: A Light in the ...
#
# Â£51.77
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Tipping the Velvet
#
# Â£53.74
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Soumission
#
# Â£50.10
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Sharp Objects
#
# Â£47.82
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Sapiens: A Brief History ...
#
# Â£54.23
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: The Requiem Red
#
# Â£22.65
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: The Dirty Little Secrets ...
#
# Â£33.34
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: The Coming Woman: A ...
#
# Â£17.93
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: The Boys in the ...
#
# Â£22.60
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: The Black Maria
#
# Â£52.15
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Starving Hearts (Triangular Trade ...
#
# Â£13.99
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Shakespeare's Sonnets
#
# Â£20.66
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Set Me Free
#
# Â£17.46
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Scott Pilgrim's Precious Little ...
#
# Â£52.29
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Rip it Up and ...
#
# Â£35.02
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Our Band Could Be ...
#
# Â£57.25
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Olio
#
# Â£23.88
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Mesaerion: The Best Science ...
#
# Â£37.59
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: Libertarianism for Beginners
#
# Â£51.33
#
#
#
#         In stock
#
#
#
# Add to basket
# Encontrado: It's Only the Himalayas
#
# Â£45.17
#
#
#
#         In stock
#
#
#
# Add to basket
# He guardado 20 diccionarios.
# {'titulo': 'A Light in the Attic', 'valor': 'Â£51.77', 'equipo': 'E-commerce'}
# {'titulo': 'Tipping the Velvet', 'valor': 'Â£53.74', 'equipo': 'E-commerce'}
# {'titulo': 'Soumission', 'valor': 'Â£50.10', 'equipo': 'E-commerce'}
# {'titulo': 'Sharp Objects', 'valor': 'Â£47.82', 'equipo': 'E-commerce'}
# {'titulo': 'Sapiens: A Brief History of Humankind', 'valor': 'Â£54.23', 'equipo': 'E-commerce'}
# {'titulo': 'The Requiem Red', 'valor': 'Â£22.65', 'equipo': 'E-commerce'}
# {'titulo': 'The Dirty Little Secrets of Getting Your Dream Job', 'valor': 'Â£33.34', 'equipo': 'E-commerce'}
# {'titulo': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'valor': 'Â£17.93', 'equipo': 'E-commerce'}
# {'titulo': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'valor': 'Â£22.60', 'equipo': 'E-commerce'}
# {'titulo': 'The Black Maria', 'valor': 'Â£52.15', 'equipo': 'E-commerce'}
# {'titulo': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'valor': 'Â£13.99', 'equipo': 'E-commerce'}
# {'titulo': "Shakespeare's Sonnets", 'valor': 'Â£20.66', 'equipo': 'E-commerce'}
# {'titulo': 'Set Me Free', 'valor': 'Â£17.46', 'equipo': 'E-commerce'}
# {'titulo': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'valor': 'Â£52.29', 'equipo': 'E-commerce'}
# {'titulo': 'Rip it Up and Start Again', 'valor': 'Â£35.02', 'equipo': 'E-commerce'}
# {'titulo': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'valor': 'Â£57.25', 'equipo': 'E-commerce'}
# {'titulo': 'Olio', 'valor': 'Â£23.88', 'equipo': 'E-commerce'}
# {'titulo': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'valor': 'Â£37.59', 'equipo': 'E-commerce'}
# {'titulo': 'Libertarianism for Beginners', 'valor': 'Â£51.33', 'equipo': 'E-commerce'}
# {'titulo': "It's Only the Himalayas", 'valor': 'Â£45.17', 'equipo': 'E-commerce'}
