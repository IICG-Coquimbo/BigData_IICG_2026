# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

todos_los_datos = []

for dato in resultados:
    titulo = dato.find('a')['title']
    
    info = {
        "titulo": titulo,
        "grupo": "Energy"
    }
    
    todos_los_datos.append(info)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])

# Guardar dataset
df = pd.DataFrame(todos_los_datos)
df.to_csv("dataset.csv", index=False)

print("Archivo dataset.csv guardado")
# Out:
# Cantidad de datos: 20
# [{'titulo': 'A Light in the Attic', 'grupo': 'Energy'}, {'titulo': 'Tipping the Velvet', 'grupo': 'Energy'}, {'titulo': 'Soumission', 'grupo': 'Energy'}]
# Archivo dataset.csv guardado

# %%
info = {
    "titulo": titulo,
    "grupo": "Energy",
    "fecha_captura": pd.Timestamp.now()
}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

todos_los_datos = []

for dato in resultados:
    titulo = dato.find('a')['title']
    
info = {
    "titulo": titulo,
    "grupo": "Energy",
    "fecha_captura": pd.Timestamp.now()
}
    
    todos_los_datos.append(info)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])

# Guardar dataset
df = pd.DataFrame(todos_los_datos)
df.to_csv("dataset.csv", index=False)

print("Archivo dataset.csv guardado")
# Out:
#   Cell In[5], line 24
#     todos_los_datos.append(info)
#     ^
# IndentationError: unexpected indent

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

todos_los_datos = []

for dato in resultados:
    titulo = dato.find('a')['title']
    
info = {
    "titulo": titulo,
    "grupo": "Energy",
    "fecha_captura": pd.Timestamp.now()
}
    
    todos_los_datos.append(info)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])

# Guardar dataset
df = pd.DataFrame(todos_los_datos)
df.to_csv("dataset.csv", index=False)

print("Archivo dataset.csv guardado")
# Out:
#   Cell In[5], line 24
#     todos_los_datos.append(info)
#     ^
# IndentationError: unexpected indent

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"}

respuesta = requests.get(url, headers=headers)
sopa = BeautifulSoup(respuesta.text, 'html.parser')

resultados = sopa.find_all('h3')

todos_los_datos = []

for dato in resultados:
    titulo = dato.find('a')['title']
    
    info = {
        "titulo": titulo,
        "grupo": "Energy",
        "fecha_captura": pd.Timestamp.now()
    }
    
    todos_los_datos.append(info)

print("Cantidad de datos:", len(todos_los_datos))
print(todos_los_datos[:3])

# Guardar dataset
df = pd.DataFrame(todos_los_datos)
df.to_csv("dataset.csv", index=False)

print("Archivo dataset.csv guardado")
# Out:
# Cantidad de datos: 20
# [{'titulo': 'A Light in the Attic', 'grupo': 'Energy', 'fecha_captura': Timestamp('2026-04-01 03:07:13.739817')}, {'titulo': 'Tipping the Velvet', 'grupo': 'Energy', 'fecha_captura': Timestamp('2026-04-01 03:07:13.739904')}, {'titulo': 'Soumission', 'grupo': 'Energy', 'fecha_captura': Timestamp('2026-04-01 03:07:13.739916')}]
# Archivo dataset.csv guardado
