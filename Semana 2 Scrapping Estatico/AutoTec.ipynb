# %%
import requests 
from bs4 import BeautifulSoup
# Configuraci n de entrada 
url = "https://hmotores.cl/bmw/" 
headers = {'User-Agent': 'Mozilla/5.0'} 

# Para que no nos bloqueen 
# 1. Petici n al servidor 
respuesta = requests.get(url, headers=headers) 
# 2. Convertir el HTML en un objeto de Python 
sopa = BeautifulSoup(respuesta.text, 'html.parser') 
# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste 
resultados = sopa.find_all('p', class_='single-vehiculo-compra-precio') 
# 4. Mostrar en pantalla 
for dato in resultados: 
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: Desde $29.900.000
# Encontrado: Desde $34.900.000
# Encontrado: Desde $36.900.000
# Encontrado: Desde $43.400.000
# Encontrado: Desde $43.900.000
# Encontrado: Desde $47.900.000
# Encontrado: Desde $52.400.000
# Encontrado: Desde $53.900.000
# Encontrado: Desde $53.900.000
# Encontrado: Desde $54.300.000
# Encontrado: Desde $55.900.000
# Encontrado: Desde $59.900.000
# Encontrado: Desde $60.900.000
# Encontrado: Desde $60.900.000
# Encontrado: Desde $60.900.000
# Encontrado: Desde $77.900.000
# Encontrado: Desde $95.900.000
# Encontrado: Desde $105.900.000
# Encontrado: Desde $118.900.000
# Encontrado: Desde $125.900.000
# Encontrado: Desde $139.900.000
# Encontrado: Desde $185.900.000
# Encontrado: Desde $188.900.000
