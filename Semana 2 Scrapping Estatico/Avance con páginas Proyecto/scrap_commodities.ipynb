# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.11/site-packages (6.0.2)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.indexmundi.com/es/precios-de-mercado/"
headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

titulo = soup.title.string
print(f"He capturado el título: {titulo}")

tabla = soup.find('table', class_='tblData')
#print(tabla)
# Out:
# He capturado el título:
# 	Precios de Materias Primas

# %%
from IPython.display import HTML

HTML(str(tabla))
# Out:
# <table border="1" cellspacing="0" class="tblData" rules="all" style="border-collapse:collapse;">
# <tr>
# <th scope="col">Commodity</th><th scope="col">Monthly Avg</th><th scope="col">1 Month Change</th><th scope="col">12 Month Change</th><th scope="col">Year to Date Change</th>
# </tr><tr>
# <td><a href="?mercancia=indice-de-materias-primas-agricolas">Indice de precios de materias primas agrícolas</a></td><td align="right">81,29</td><td align="right">0,31 %</td><td align="right">1,27 %</td><td align="right">-1,37 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-alimentos">Indice de precios de alimentos</a></td><td align="right">106,75</td><td align="right">-1,43 %</td><td align="right">-7,26 %</td><td align="right">-6,69 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-alimentos-y-bebidas">Indice de precios de alimentos y bebidas</a></td><td align="right">133,01</td><td align="right">-2,49 %</td><td align="right">-2,53 %</td><td align="right">-8,88 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-bebidas">Indice de precios de bebidas</a></td><td align="right">207,95</td><td align="right">-8,23 %</td><td align="right" style="background-color:LightGreen;">10,70 %</td><td align="right" style="background-color:LightPink;">-12,93 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-combustibles">Indice de precios de combustibles (energía)</a></td><td align="right">92,19</td><td align="right">9,69 %</td><td align="right" style="background-color:LightPink;">-11,16 %</td><td align="right" style="background-color:LightPink;">-10,95 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-insumos-industriales">Indice de precios de insumos industriales</a></td><td align="right">159,16</td><td align="right">0,71 %</td><td align="right">-2,90 %</td><td align="right">0,07 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-del-petroleo-crudo">Indice de precios del petróleo crudo</a></td><td align="right">163,12</td><td align="right">8,48 %</td><td align="right" style="background-color:LightPink;">-18,67 %</td><td align="right" style="background-color:LightPink;">-15,60 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-metales">Indice de precios de metales</a></td><td align="right">108,66</td><td align="right">1,73 %</td><td align="right">-1,77 %</td><td align="right">2,52 %</td>
# </tr><tr>
# <td><a href="?mercancia=indice-de-precios-de-no-combustibles">Indice de precios de no-combustibles</a></td><td align="right">112,93</td><td align="right">-1,05 %</td><td align="right">-1,07 %</td><td align="right">-3,68 %</td>
# </tr><tr>
# </tr><tr>
# <td><a href="?mercancia=petroleo-crudo-texas">Petróleo crudo oeste de Texas intermedio</a></td><td align="right">67,49</td><td align="right" style="background-color:LightGreen;">10,58 %</td><td align="right" style="background-color:LightPink;">-14,45 %</td><td align="right" style="background-color:LightPink;">-10,18 %</td>
# </tr><tr>
# <td><a href="?mercancia=propano">Propano</a></td><td align="right">0,76</td><td align="right">1,34 %</td><td align="right">-0,79 %</td><td align="right" style="background-color:LightPink;">-16,09 %</td>
# </tr><tr>
# <td><a href="?mercancia=cafe-arabica">Café, arábica suave</a></td><td align="right">8,01</td><td align="right">-8,67 %</td><td align="right" style="background-color:LightGreen;">46,17 %</td><td align="right">2,56 %</td>
# </tr><tr>
# <td><a href="?mercancia=cafe-robusta">Café, robusta</a></td><td align="right">4,33</td><td align="right" style="background-color:LightPink;">-17,37 %</td><td align="right">-3,78 %</td><td align="right" style="background-color:LightPink;">-19,96 %</td>
# </tr><tr>
# <td><a href="?mercancia=granos-de-cacao">Cacao en grano</a></td><td align="right">8,40</td><td align="right">-6,56 %</td><td align="right">1,57 %</td><td align="right" style="background-color:LightPink;">-21,86 %</td>
# </tr><tr>
# <td><a href="?mercancia=te">Té</a></td><td align="right">2,00</td><td align="right">4,71 %</td><td align="right">-6,54 %</td><td align="right" style="background-color:LightPink;">-10,71 %</td>
# </tr><tr>
# <td><a href="?mercancia=arroz">Arroz</a></td><td align="right">419,00</td><td align="right">-2,78 %</td><td align="right" style="background-color:LightPink;">-33,70 %</td><td align="right" style="background-color:LightPink;">-12,34 %</td>
# </tr><tr>
# <td><a href="?mercancia=cebada">Cebada</a></td><td align="right"> </td><td> </td><td> </td><td> </td>
# </tr><tr>
# <td><a href="?mercancia=maiz">Maíz</a></td><td align="right">196,07</td><td align="right">-3,83 %</td><td align="right">1,85 %</td><td align="right">-8,57 %</td>
# </tr><tr>
# <td><a

# %%
import pandas as pd

df = pd.read_html(str(tabla))[0]
df.to_csv('precios_materias_primas.csv', index=False)
df
# Out:
#                                          Commodity Monthly Avg 1 Month Change  \
# 0   Indice de precios de materias primas agrícolas        8129         0,31 %
# 1                   Indice de precios de alimentos       10675        -1,43 %
# 2         Indice de precios de alimentos y bebidas       13301        -2,49 %
# 3                     Indice de precios de bebidas       20795        -8,23 %
# 4      Indice de precios de combustibles (energía)        9219         9,69 %
# ..                                             ...         ...            ...
# 85                              Cloruro de potasio       36313         0,17 %
# 86                         Fosfato diamónico (DAP)       71538         6,90 %
# 87                                       Fosforita       15250         0,00 %
# 88                             Superfosfato triple       64125        18,42 %
# 89                                            Urea       42050         7,27 %
#
#    12 Month Change Year to Date Change
# 0           1,27 %             -1,37 %
# 1          -7,26 %             -6,69 %
# 2          -2,53 %             -8,88 %
# 3          10,70 %            -12,93 %
# 4         -11,16 %            -10,95 %
# ..             ...                 ...
# 85         17,14 %             20,24 %
# 86         31,75 %             22,77 %
# 87          0,00 %              0,00 %
# 88         35,36 %             34,15 %
# 89         25,06 %             10,51 %
#
# [90 rows x 5 columns]
