# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://books.toscrape.com/"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor

respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, "html.parser")

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
 # Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('article', class_= 'product_pod')




todos_los_datos = [] # Lista vacia para guardar todo

for item in resultados:
#Creamos el diccionario para ESTE producto
    datos_item = {
        "titulo":item.find('h3').text.strip(),
        "valor": item.find('div', class_= 'product_price').text.strip(),
        
    }

# Lo agregamos a nuestra lista general
    todos_los_datos.append(datos_item)
    
    print(f"{datos_item['titulo']} - {datos_item['valor']}")

# Ahora tenemos una "colecci n" lista para MongoDB
print(f"He guardado {len(todos_los_datos)} diccionarios.")

for diccionarios in todos_los_datos:
    print(diccionarios)
# Out:
# A Light in the ... - Â£51.77
#
#
#
#         In stock
#
#
#
# Add to basket
# Tipping the Velvet - Â£53.74
#
#
#
#         In stock
#
#
#
# Add to basket
# Soumission - Â£50.10
#
#
#
#         In stock
#
#
#
# Add to basket
# Sharp Objects - Â£47.82
#
#
#
#         In stock
#
#
#
# Add to basket
# Sapiens: A Brief History ... - Â£54.23
#
#
#
#         In stock
#
#
#
# Add to basket
# The Requiem Red - Â£22.65
#
#
#
#         In stock
#
#
#
# Add to basket
# The Dirty Little Secrets ... - Â£33.34
#
#
#
#         In stock
#
#
#
# Add to basket
# The Coming Woman: A ... - Â£17.93
#
#
#
#         In stock
#
#
#
# Add to basket
# The Boys in the ... - Â£22.60
#
#
#
#         In stock
#
#
#
# Add to basket
# The Black Maria - Â£52.15
#
#
#
#         In stock
#
#
#
# Add to basket
# Starving Hearts (Triangular Trade ... - Â£13.99
#
#
#
#         In stock
#
#
#
# Add to basket
# Shakespeare's Sonnets - Â£20.66
#
#
#
#         In stock
#
#
#
# Add to basket
# Set Me Free - Â£17.46
#
#
#
#         In stock
#
#
#
# Add to basket
# Scott Pilgrim's Precious Little ... - Â£52.29
#
#
#
#         In stock
#
#
#
# Add to basket
# Rip it Up and ... - Â£35.02
#
#
#
#         In stock
#
#
#
# Add to basket
# Our Band Could Be ... - Â£57.25
#
#
#
#         In stock
#
#
#
# Add to basket
# Olio - Â£23.88
#
#
#
#         In stock
#
#
#
# Add to basket
# Mesaerion: The Best Science ... - Â£37.59
#
#
#
#         In stock
#
#
#
# Add to basket
# Libertarianism for Beginners - Â£51.33
#
#
#
#         In stock
#
#
#
# Add to basket
# It's Only the Himalayas - Â£45.17
#
#
#
#         In stock
#
#
#
# Add to basket
# He guardado 20 diccionarios.
# {'titulo': 'A Light in the ...', 'valor': 'Â£51.77\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Tipping the Velvet', 'valor': 'Â£53.74\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Soumission', 'valor': 'Â£50.10\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Sharp Objects', 'valor': 'Â£47.82\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Sapiens: A Brief History ...', 'valor': 'Â£54.23\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'The Requiem Red', 'valor': 'Â£22.65\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'The Dirty Little Secrets ...', 'valor': 'Â£33.34\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'The Coming Woman: A ...', 'valor': 'Â£17.93\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'The Boys in the ...', 'valor': 'Â£22.60\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'The Black Maria', 'valor': 'Â£52.15\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Starving Hearts (Triangular Trade ...', 'valor': 'Â£13.99\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': "Shakespeare's Sonnets", 'valor': 'Â£20.66\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Set Me Free', 'valor': 'Â£17.46\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': "Scott Pilgrim's Precious Little ...", 'valor': 'Â£52.29\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Rip it Up and ...', 'valor': 'Â£35.02\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Our Band Could Be ...', 'valor': 'Â£57.25\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Olio', 'valor': 'Â£23.88\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Mesaerion: The Best Science ...', 'valor': 'Â£37.59\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': 'Libertarianism for Beginners', 'valor': 'Â£51.33\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
# {'titulo': "It's Only the Himalayas", 'valor': 'Â£45.17\n\n\n    \n        In stock\n    \n\n\nAdd to basket'}
