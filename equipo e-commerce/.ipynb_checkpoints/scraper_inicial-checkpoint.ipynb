# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://books.toscrape.com"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('article', class_='product_pod')


# 4. Mostrar en pantalla
#for dato in resultados:
 # print(f"Encontrado: {dato.text.strip()}")
   
    
todos_los_datos = [] # Lista vacia para guardar todo

for item in resultados:
# Creamos el diccionario para ESTE producto
    datos_item = {
        "titulo": item.find('h3').find('a')['title'],
        "valor": item.find('p', class_='price_color').text.strip(),
        "grupo": "E-commerce" # Etiqueta de tu caso de estudio
}
    todos_los_datos.append(datos_item)

# Ahora tenemos una "colecci n" lista para MongoDB
print(f"He guardado {len(todos_los_datos)} diccionarios.")

for diccionario in todos_los_datos:
    print(diccionario)
# Out:
# He guardado 20 diccionarios.
# {'titulo': 'A Light in the Attic', 'valor': 'Â£51.77', 'grupo': 'E-commerce'}
# {'titulo': 'Tipping the Velvet', 'valor': 'Â£53.74', 'grupo': 'E-commerce'}
# {'titulo': 'Soumission', 'valor': 'Â£50.10', 'grupo': 'E-commerce'}
# {'titulo': 'Sharp Objects', 'valor': 'Â£47.82', 'grupo': 'E-commerce'}
# {'titulo': 'Sapiens: A Brief History of Humankind', 'valor': 'Â£54.23', 'grupo': 'E-commerce'}
# {'titulo': 'The Requiem Red', 'valor': 'Â£22.65', 'grupo': 'E-commerce'}
# {'titulo': 'The Dirty Little Secrets of Getting Your Dream Job', 'valor': 'Â£33.34', 'grupo': 'E-commerce'}
# {'titulo': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'valor': 'Â£17.93', 'grupo': 'E-commerce'}
# {'titulo': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'valor': 'Â£22.60', 'grupo': 'E-commerce'}
# {'titulo': 'The Black Maria', 'valor': 'Â£52.15', 'grupo': 'E-commerce'}
# {'titulo': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'valor': 'Â£13.99', 'grupo': 'E-commerce'}
# {'titulo': "Shakespeare's Sonnets", 'valor': 'Â£20.66', 'grupo': 'E-commerce'}
# {'titulo': 'Set Me Free', 'valor': 'Â£17.46', 'grupo': 'E-commerce'}
# {'titulo': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'valor': 'Â£52.29', 'grupo': 'E-commerce'}
# {'titulo': 'Rip it Up and Start Again', 'valor': 'Â£35.02', 'grupo': 'E-commerce'}
# {'titulo': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'valor': 'Â£57.25', 'grupo': 'E-commerce'}
# {'titulo': 'Olio', 'valor': 'Â£23.88', 'grupo': 'E-commerce'}
# {'titulo': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'valor': 'Â£37.59', 'grupo': 'E-commerce'}
# {'titulo': 'Libertarianism for Beginners', 'valor': 'Â£51.33', 'grupo': 'E-commerce'}
# {'titulo': "It's Only the Himalayas", 'valor': 'Â£45.17', 'grupo': 'E-commerce'}
